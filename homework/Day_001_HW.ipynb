# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 253.244
# The Mean absolute error is 13.076

# %%
# [作業2]

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
ANS :Novel Corona Virus 2019 Dataset
主要新型冠狀病毒(COVID-19)與目前己知病毒的形能不同, 對於它如何在人類傳播並不清楚,
此份數據蒐集了目前感染人數,分布地區,日期,及治癒人數等,可了解COVID-19的感染速度,範圍及控制情況
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
ANS:資料由WHO(世界衛生組織) CDC(美國疾病管制與預防中心) NHC(中華人民共和國國家衛生健康委員會) 和 DXY (丁香園)提供
並由Johns Hopkins 大學整理
3. 蒐集而來的資料型態為何
ANS:日期/人數/地區/國藉/是否確診(True/False)
4. 這組資料想解決的問題如何評估
ANS:可由
a.感染人數隨時間的變化
b.各國感染情況隨時間變化
c.最近感染數是否增加或減少 
來評估疫情是否得到控制, 或是在哪區開始爆發。

# [作業3]

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
ANS:業績提昇可由營收提高、空車時間減低、接單數量、客戶回頭率評估
    自由載客車隊與傳統車隊比較起來, 沒有固定的排點(高鐵,機場)等, 通常是藉由電話來接洽業務
假設目前的業績未達理想,是由於接單及出車尚未最佳化, 因此要如何有效率地調度人力, 穩定地派車, 
減少團隊空車時間以避免客戶等待過久, 車輛閒置,或尖峰時段無車而影響車隊的穩定性, 進而對業績提升就有相當重要的影響。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
ANS從叫車記錄, 取得叫車人數,叫車時間,客戶資料
從GPS取得行車路線, 行車時間,空車時間, 到達叫車地點的時間
從結帳系統取得金額
從其他系統取得客戶滿意度等資料

3. 蒐集而來的資料型態為何
ANS 結構化資料-數值和類別資料 :ex:日期/時間/金額/里程...等
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
分析目前出車情況, 長途及短程所花的時間及收益,以及固定路線的需求度,找出適當的長短程搭配方式以減少空車的時間
從GPS路徑及載客時間可以看出是否減少每趟間的移動距離及等待時間,看是否對於業績增長有正面效益提昇。
